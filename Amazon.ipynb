# %%
import pandas as pd

# %%
df=pd.read_csv('amzone.csv',usecols=['Id','Score','Text'],on_bad_lines='skip')
df=df.sample(500,random_state=42)

# %%
df
# Out:
#           Id  Score                                               Text
# 25739  25740    4.0  This is the only veggie jerquee my local groce...
# 12585  12586    5.0  Our local stores have stopped carrying this pr...
# 15737  15738    5.0  Really a great cup of coffee.Rich and mellow, ...
# 1138    1139    3.0  As the ingredients contained in this food are ...
# 12833  12834    5.0  I'm just a droolin' fool thinkin' about these ...
# ...      ...    ...                                                ...
# 21322  21323    5.0  The price is excellent and the product arrived...
# 17702  17703    5.0  This mild tea is great any time of day, howeve...
# 15594  15595    5.0  My Husky has always been a little 'picky' when...
# 24667  24668    5.0  When you eat this granola you have tast and th...
# 11746  11747    5.0  I grew up on King Golden Syrup back in Pennsyl...
#
# [500 rows x 3 columns]

# %%
import re
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
from nltk.corpus import stopwords #a ,and ,the
from nltk.tokenize import word_tokenize
stopwords_set=set(stopwords.words('english'))

# %%
def Clean_Txt(text):# I LOVE THe Food <3
  text=text.lower()#  i love the food <3
  text=re.sub(r'[^a-z\s]',' ',text)#  i love the food
  tokens=word_tokenize(text) #["i","love","the","food"]
  tokens=[i for i in tokens if i not in stopwords_set] #["love","food"]
  return ' '.join(tokens)# love food

# %%
df["cleaned_text"]=df['Text'].apply(Clean_Txt)

# %%
from textblob import TextBlob
def sentiment(text):
  p=TextBlob(text).sentiment.polarity
  if p>0:
    return 'Positive'
  elif p<0:
    return 'Negative'
  else:
    return "Neutral"
df["sentiment"]=df['cleaned_text'].apply(sentiment)

# %%
df
# Out:
#           Id  Score                                               Text  \
# 25739  25740    4.0  This is the only veggie jerquee my local groce...
# 12585  12586    5.0  Our local stores have stopped carrying this pr...
# 15737  15738    5.0  Really a great cup of coffee.Rich and mellow, ...
# 1138    1139    3.0  As the ingredients contained in this food are ...
# 12833  12834    5.0  I'm just a droolin' fool thinkin' about these ...
# ...      ...    ...                                                ...
# 21322  21323    5.0  The price is excellent and the product arrived...
# 17702  17703    5.0  This mild tea is great any time of day, howeve...
# 15594  15595    5.0  My Husky has always been a little 'picky' when...
# 24667  24668    5.0  When you eat this granola you have tast and th...
# 11746  11747    5.0  I grew up on King Golden Syrup back in Pennsyl...
#
#                                             cleaned_text sentiment
# ...

# %%
for i in range(4):
  print(f"Original:{df['Text'].iloc[i]}")
  print(f"Cleaned:{df['cleaned_text'].iloc[i]}")
# Out:
# Original:This is the only veggie jerquee my local grocery store carries and is a good substitute for when I don't feel like ordering my favorite(stonewalls) online.<br />I like the flavor and the texture but I always need scissors to open the package and I hate the thought of my germy scissors touching my food.<br />Once you finally open it, it's hard to really get a good bite because it is very stringy and full of sauce, you usually end up with half the product in one bite just so you don't get sauce all over your hands and mouth.<br />I often get it stuck in my teeth too, which is annoying when I'm at work without dental floss.<br />I think they are redesigning the package so hopefully it will be easier to eat soon. They could work on the price too, $1.29 at the store for 2 bites is a bit ridiculous!
# ...
